# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("cleantrain.csv")

# %%
# 1 Understand the data

# %%
data.head()
# Out:
#    MSSubClass  LotArea BldgType  OverallCond  YearBuilt  YearRemodAdd  Age  \
# 0          60     8450     1Fam            5       2003          2003    8
# 1          60    11250     1Fam            5       2001          2002   10
# 2          60    14260     1Fam            5       2000          2000   11
# 3          60    10382     1Fam            6       1973          1973   38
# 4          60    13418     1Fam            5       2004          2005    7
#
#    Remodel Age Foundation  BsmtUnfSF  ...  HalfBath  TotalFullBath  \
# 0            8      PConc        150  ...         1              3
# 1            9      PConc        434  ...         1              3
# 2           11      PConc        490  ...         1              3
# 3           38     CBlock        216  ...         1              3
# 4            6      PConc       1117  ...         1              3
#
#    TotalHalfBath  TotalBath  BedroomAbvGr  TotRmsAbvGrd  GarageCars  MoSold  \
# ...

# %%
data.tail()
# Out:
#      MSSubClass  LotArea BldgType  OverallCond  YearBuilt  YearRemodAdd  Age  \
# 352          60    11103     1Fam            5       2006          2006    5
# 353          60     8499     1Fam            5       2006          2007    5
# 354         160     3951   TwnhsE            5       2009          2009    2
# 355         160     4251   TwnhsE            5       2006          2007    5
# 356         160     3000   TwnhsE            5       2009          2009    2
#
#      Remodel Age Foundation  BsmtUnfSF  ...  HalfBath  TotalFullBath  \
# 352            5      PConc        728  ...         1              2
# 353            4      PConc        616  ...         1              2
# 354            2      PConc        612  ...         1              2
# 355            4      PConc        625  ...         1              2
# 356            2      PConc        318  ...         1              2
#
#      TotalHalfBath  TotalBath  BedroomAbvGr  TotRmsAbvGrd  GarageCars  MoSold  \
# ...

# %%
data.shape
# Out:
# (357, 27)

# %%
data.describe()
# Out:
#        MSSubClass       LotArea  OverallCond    YearBuilt  YearRemodAdd  \
# count  357.000000    357.000000   357.000000   357.000000    357.000000
# mean    76.274510  10510.341737     5.338936  1990.403361   1994.697479
# std     36.280551   6775.148236     0.841329    20.871861     13.335486
# min     60.000000   1300.000000     3.000000  1880.000000   1950.000000
# 25%     60.000000   8123.000000     5.000000  1978.000000   1991.000000
# 50%     60.000000   9965.000000     5.000000  1998.000000   1999.000000
# 75%     60.000000  12203.000000     5.000000  2004.000000   2005.000000
# max    160.000000  63887.000000     9.000000  2009.000000   2010.000000
#
#               Age  Remodel Age    BsmtUnfSF    BsmtFinSF  TotalBsmtSF  ...  \
# count  357.000000   357.000000   357.000000   357.000000   357.000000  ...
# mean    20.596639    16.302521   545.263305   425.756303   971.019608  ...
# std     20.871861    13.335486   381.827257   491.948407   421.563459  ...
# ...

# %%
data.columns
# Out:
# Index(['MSSubClass', 'LotArea', 'BldgType', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'Age', 'Remodel Age', 'Foundation', 'BsmtUnfSF',
#        'BsmtFinSF', 'TotalBsmtSF', 'GrLivArea', 'TotalFinSF', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'TotalFullBath',
#        'TotalHalfBath', 'TotalBath', 'BedroomAbvGr', 'TotRmsAbvGrd',
#        'GarageCars', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
# Find number of unique values in each column
data.nunique()
# Out:
# MSSubClass         3
# LotArea          315
# BldgType           3
# OverallCond        7
# YearBuilt         57
# YearRemodAdd      46
# Age               57
# Remodel Age       46
# Foundation         5
# BsmtUnfSF        279
# BsmtFinSF        205
# TotalBsmtSF      256
# GrLivArea        294
# TotalFinSF       318
# BsmtFullBath       3
# BsmtHalfBath       2
# FullBath           3
# HalfBath           3
# TotalFullBath      4
# TotalHalfBath      4
# TotalBath          8
# BedroomAbvGr       4
# TotRmsAbvGrd       9
# GarageCars         4
# MoSold            12
# YrSold             5
# SalePrice        257
# dtype: int64

# %%
data['OverallCond'].unique()
# Out:
# array([5, 6, 8, 9, 7, 4, 3], dtype=int64)

# %%
data['Foundation'].unique()
# Out:
# array(['PConc', 'CBlock', 'Slab', 'Wood', 'BrkTil'], dtype=object)

# %%
# Check for null values
data.isnull().sum()
# Out:
# MSSubClass       0
# LotArea          0
# BldgType         0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# Age              0
# Remodel Age      0
# Foundation       0
# BsmtUnfSF        0
# BsmtFinSF        0
# TotalBsmtSF      0
# GrLivArea        0
# TotalFinSF       0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# TotalFullBath    0
# TotalHalfBath    0
# TotalBath        0
# BedroomAbvGr     0
# TotRmsAbvGrd     0
# GarageCars       0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %%
# Drop unneeded columns
houses = data.drop(['MSSubClass', 'BldgType', 'Age', 'Remodel Age', 'BsmtUnfSF', 'BsmtFinSF', 'TotalBsmtSF', 'GrLivArea','BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'TotalFullBath', 'TotalHalfBath', 'MoSold'], axis=1)

# %%
houses.head(n=15)
# Out:
#     LotArea  OverallCond  YearBuilt  YearRemodAdd Foundation  TotalFinSF  \
# 0      8450            5       2003          2003      PConc        2416
# 1     11250            5       2001          2002      PConc        2272
# 2     14260            5       2000          2000      PConc        2853
# 3     10382            6       1973          1973     CBlock        2981
# 4     13418            5       2004          2005      PConc        2452
# 5     13869            6       1997          1997      PConc        1652
# 6     11645            5       2004          2004      PConc        1720
# 7      9375            5       1997          1998      PConc        2773
# 8      9591            5       2004          2005      PConc        2473
# 9     10141            5       1998          1998      PConc        1718
# 10    13000            6       1968          1968     CBlock        2590
# 11    16059            5       1991          1992     CBlock        2417
# ...

# %%
houses.tail(n=15)
# Out:
#      LotArea  OverallCond  YearBuilt  YearRemodAdd Foundation  BsmtUnfSF  \
# 342    10237            5       2005          2007      PConc        783
# 343     8125            5       2006          2006      PConc        770
# 344     8846            5       2005          2006      PConc        750
# 345    16056            5       2005          2006      PConc       1752
# 346    23257            5       2006          2006      PConc        868
# 347     9965            5       2006          2007      PConc        316
# 348    14054            5       2006          2006      PConc        879
# 349     8125            5       2005          2006      PConc        756
# 350    11065            5       2006          2006      PConc       1085
# 351    63887            5       2008          2008      PConc        466
# 352    11103            5       2006          2006      PConc        728
# 353     8499            5       2006          2007      PConc        616
# ...

# %%
houses.shape
# Out:
# (357, 12)

# %%
# Relationship Analysis

# %%
correlation = houses.corr()
# Out:
# C:\Users\amber\AppData\Local\Temp\ipykernel_12164\1404039378.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = houses.corr()

# %%
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True)
plt.savefig("heatmap")

# %%
sns.pairplot(houses, hue='GarageCars', x_vars="SalePrice")

# %%
sns.relplot(x='TotalFinSF', y='SalePrice', hue='BedroomAbvGr', data=houses)
